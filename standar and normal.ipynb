# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd MyDrive/dataset
# Out:
# /gdrive/MyDrive/dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("winequality-red.csv",sep=";")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
#
# [3 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split

# %%
df2=df.dropna(axis=1)

# %%
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
y=df2['fixed acidity']
x=df2.drop('fixed acidity',inplace=False,axis=1)

# %%
y.head(3)
# Out:
# 0    7.4
# 1    7.8
# 2    7.8
# Name: fixed acidity, dtype: float64

# %%
x.head(3)
# Out:
#    volatile acidity  citric acid  residual sugar  ...  sulphates  alcohol  quality
# 0              0.70         0.00             1.9  ...       0.56      9.4        5
# 1              0.88         0.00             2.6  ...       0.68      9.8        5
# 2              0.76         0.04             2.3  ...       0.65      9.8        5
#
# [3 rows x 11 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=7,test_size=0.2)

# %%
x_train.head(3)
# Out:
#       volatile acidity  citric acid  ...  alcohol  quality
# 363              0.460         0.63  ...     10.2        5
# 1385             0.810         0.25  ...      9.2        5
# 370              0.765         0.02  ...      9.9        5
#
# [3 rows x 11 columns]

# %%
y_train.head(3)
# Out:
# 363     12.5
# 1385     8.0
# 370      6.9
# Name: fixed acidity, dtype: float64

# %%
x_test.head(3)
# Out:
#       volatile acidity  citric acid  ...  alcohol  quality
# 1526              0.47         0.08  ...      9.6        6
# 674               0.40         0.41  ...      9.3        6
# 1508              0.27         0.60  ...     10.6        6
#
# [3 rows x 11 columns]

# %%
y_test.head(3)
# Out:
# 1526     6.8
# 674     10.8
# 1508     7.1
# Name: fixed acidity, dtype: float64

# %%
x_train.describe()
# Out:
#        volatile acidity  citric acid  ...      alcohol      quality
# count       1279.000000  1279.000000  ...  1279.000000  1279.000000
# mean           0.529957     0.268014  ...    10.399453     5.621579
# std            0.177191     0.193631  ...     1.055490     0.817858
# min            0.120000     0.000000  ...     8.400000     3.000000
# 25%            0.400000     0.090000  ...     9.500000     5.000000
# 50%            0.520000     0.260000  ...    10.100000     6.000000
# 75%            0.640000     0.420000  ...    11.000000     6.000000
# max            1.580000     1.000000  ...    14.000000     8.000000
#
# [8 rows x 11 columns]

# %%
y_train.describe()
# Out:
# count    1279.000000
# mean        8.285457
# std         1.730476
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.100000
# max        15.600000
# Name: fixed acidity, dtype: float64

# %%
x_test.describe()
# Out:
#        volatile acidity  citric acid  ...     alcohol     quality
# count        320.000000   320.000000  ...  320.000000  320.000000
# mean           0.519281     0.282813  ...   10.517031    5.693750
# std            0.186384     0.199277  ...    1.102092    0.763566
# min            0.180000     0.000000  ...    9.000000    4.000000
# 25%            0.380000     0.100000  ...    9.575000    5.000000
# 50%            0.500000     0.260000  ...   10.300000    6.000000
# 75%            0.620000     0.440000  ...   11.300000    6.000000
# max            1.330000     0.780000  ...   14.900000    8.000000
#
# [8 rows x 11 columns]

# %%
y_test.describe()
# Out:
# count    320.000000
# mean       8.456250
# std        1.779109
# min        4.700000
# 25%        7.200000
# 50%        8.050000
# 75%        9.525000
# max       15.900000
# Name: fixed acidity, dtype: float64

# %%
from pandas.core.tools.datetimes import Scalar
Scalar = StandardScaler().fit(x_train)
standardize_x_train = Scalar.transform(x_train)
standardize_x_test = Scalar.transform(x_test)

# %%
print(standardize_x_train)
# Out:
# [[-0.39496664  1.87019105 -0.38398375 ...  1.22458693 -0.18904093
#   -0.76030583]
#  [ 1.58108048 -0.09306925  0.59176493 ... -1.37734384 -1.13683921
#   -0.76030583]
#  [ 1.32701728 -1.28135838 -0.17489475 ...  0.70420078 -0.47338041
#   -0.76030583]
#  ...
#  [ 1.66576821 -0.144734   -0.31428742 ...  0.64638009  0.28485822
#    0.46287801]
#  [-1.18538548  1.30187886 -0.52337642 ...  0.64638009  1.04309685
#    0.46287801]
#  [-0.16913268 -1.17802889 -0.73246542 ...  0.70420078 -0.85249973
#   -0.76030583]]

# %%
from pandas.core.tools.datetimes import Scalar
normalizer = Normalizer().fit(x_train)
normalizer_x_train = normalizer.transform(x_train)
normalizer_x_test = normalizer.transform(x_test)

# %%
print(normalizer_x_train)
# Out:
# [[2.28477658e-02 3.12915053e-02 9.93381121e-02 ... 4.32120788e-02
#   5.06624372e-01 2.48345280e-01]
#  [8.77831788e-03 2.70935737e-03 3.68472602e-02 ... 4.55172038e-03
#   9.97043512e-02 5.41871474e-02]
#  [1.04713615e-02 2.73761086e-04 3.14825249e-02 ... 1.06766824e-02
#   1.35511738e-01 6.84402715e-02]
#  ...
#  [4.33257753e-02 1.26038619e-02 1.10283792e-01 ... 4.04373903e-02
#   5.61922177e-01 3.15096548e-01]
#  [6.51945345e-03 1.05941119e-02 3.66719256e-02 ... 1.56874349e-02
#   2.34292858e-01 1.22239752e-01]
#  [9.29666569e-03 7.43733255e-04 2.78899971e-02 ... 1.45027985e-02
#   1.76636648e-01 9.29666569e-02]]

# %%
x=df2.drop('fixed acidity',axis=1)
y=df2['fixed acidity']
y=np.asarray(df2['fixed acidity'], dtype="|S6")

# %%
from sklearn.feature_selection import chi2
chi_scores = chi2(x,y)
chi_scores
# Out:
# (array([1.58491481e+01, 1.12361278e+02, 1.10276060e+02, 2.95803335e+00,
#         9.19740345e+02, 3.53075847e+03, 2.90128022e-03, 6.41519174e+00,
#         8.38408914e+00, 3.44338051e+01, 2.08852543e+01]),
#  array([1.00000000e+000, 1.07903898e-001, 1.35311454e-001, 1.00000000e+000,
#         3.66585611e-135, 0.00000000e+000, 1.00000000e+000, 1.00000000e+000,
#         1.00000000e+000, 9.99999999e-001, 1.00000000e+000]))

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Column Names','Scores of columns']

print(featureScores.nlargest(10,'Scores of columns'))
# Out:
#             Column Names  Scores of columns
# 5   total sulfur dioxide        3530.758469
# 4    free sulfur dioxide         919.740345
# 1            citric acid         112.361278
# 2         residual sugar         110.276060
# 9                alcohol          34.433805
# 10               quality          20.885254
# 0       volatile acidity          15.849148
# 8              sulphates           8.384089
# 7                     pH           6.415192
# 3              chlorides           2.958033
