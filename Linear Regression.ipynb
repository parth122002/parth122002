# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd MyDrive/dataset
# Out:
# /gdrive/MyDrive/dataset

# %%
# %ls
# Out:
# accessories.csv        covtype.csv   data.csv
# Admission_Predict.csv  covtype.data  fullspecs.csv
# cancer.csv             cwurData.csv  winequality-red.csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]

# %%
df2=df.dropna(axis=1)
df2
# Out:
#        Unnamed: 0      ID                Name  ...    Value   Wage Special
# 0               0  158023            L. Messi  ...  €110.5M  €565K    2202
# 1               1   20801   Cristiano Ronaldo  ...     €77M  €405K    2228
# 2               2  190871           Neymar Jr  ...  €118.5M  €290K    2143
# 3               3  193080              De Gea  ...     €72M  €260K    1471
# 4               4  192985        K. De Bruyne  ...    €102M  €355K    2281
# ...           ...     ...                 ...  ...      ...    ...     ...
# 18202       18202  238813        J. Lundstram  ...     €60K    €1K    1307
# 18203       18203  243165  N. Christoffersson  ...     €60K    €1K    1098
# 18204       18204  241638           B. Worman  ...     €60K    €1K    1189
# 18205       18205  246268      D. Walker-Rice  ...     €60K    €1K    1228
# 18206       18206  246269           G. Nugent  ...     €60K    €1K    1321
#
# [18207 rows x 13 columns]

# %%
df['Release Clause'] = df['Release Clause'].str.replace(r"€","")
df['Release Clause'] = df['Release Clause'].str.replace(r"M","")
df['Release Clause'] = df['Release Clause'].str.replace(r"K","")
df['Release Clause'] = df['Release Clause'].astype(float)

# %%
x = df.Potential[:1000]

# %%
y=df['Release Clause'][:1000]

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
mean_x =x.mean()
mean_y=y.mean()

# %%
print("Mean for X values is",mean_x)
print("Mean for y values is",mean_y)
# Out:
# Mean for X values is 82.507
# Mean for y values is 36.44715789473684

# %%
plt.scatter(x,y, color='blue')
plt.show()

# %%
x = df.Potential[:1000]

# %%
tempx = [(i-mean_x)**2 for i in x] 
var_x = sum(tempx,0)/(len(tempx)-1)

tempy = [(i-mean_y)**2 for i in y] 
var_y = sum(tempy,0)/(len(tempy)-1)

print(var_x,var_y)
# Out:
# 14.066017017016927 nan
